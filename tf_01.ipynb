# %% [markdown]
# <a href="https://colab.research.google.com/github/minzzii-kim/machine-learing/blob/main/tf_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 파일 업로드하기

# %% [markdown]
# 1. 직접 업로드

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-1e0c0895-1f95-403d-9695-4ac0bd6ef5a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e0c0895-1f95-403d-9695-4ac0bd6ef5a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving house_price.csv to house_price.csv

# %%
import io
import pandas as pd

# %%
myfile
# Out:
# {'house_price.csv': b'\xef\xbb\xbf\xec\xa7\x80\xec\x97\xad\xeb\xaa\x85,\xea\xb7\x9c\xeb\xaa\xa8\xea\xb5\xac\xeb\xb6\x84,\xec\x97\xb0\xeb\x8f\x84,\xec\x9b\x94,\xeb\xb6\x84\xec\x96\x91\xea\xb0\x80\xea\xb2\xa9(\xe3\x8e\xa1)\r\n\xec\x84\x9c\xec\x9a\xb8,\xec\xa0\x84\xec\x9a\xa9\xeb\xa9\xb4\xec\xa0\x81 60\xe3\x8e\xa1\xec\x9d\xb4\xed\x95\x98,2015,10,5652\r\n\xec\x84\x9c\xec\x9a\xb8,\xec\xa0\x84\xec\x9a\xa9\xeb\xa9\xb4\xec\xa0\x81 60\xe3\x8e\xa1\xec\xb4\x88\xea\xb3\xbc 85\xe3\x8e\xa1\xec\x9d\xb4\xed\x95\x98,2015,10,5882\r\n\xec\x84\x9c\xec\x9a\xb8,\xec\xa0\x84\xec\x9a\xa9\xeb\xa9\xb4\xec\xa0\x81 85\xe3\x8e\xa1\xec\xb4\x88\xea\xb3\xbc 102\xe3\x8e\xa1\xec\x9d\xb4\xed\x95\x98,2015,10,5721\r\n\xec\x84\x9c\xec\x9a\xb8,\xec\xa0\x84\xec\x9a\xa9\xeb\xa9\xb4\xec\xa0\x81 102\xe3\x8e\xa1\xec\xb4\x88\xea\xb3\xbc,2015,10,5879\r\n\xec\x9d\xb8\xec\xb2\x9c,\xec\xa0\x84\xec\x9a\xa9\xeb\xa9\xb4\xec\xa0\x81 60\xe3\x8e\xa1\xec\x9d\xb4\xed\x95\x98,2015,10,3488\r\n\xec\x9d\xb8\xec\xb2\x9c,\xec\xa0\x84\xec\x9a\xa9
# ...

# %% [markdown]
# 'house_price.csv', the key value is the name of the uploaded file

# %%
import io
import pandas as pd
data = pd.read_csv(io.BytesIO(myfile['house_price.csv']))

# %%
data.head()
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울         전용면적 60㎡이하  2015  10    5652
# 1  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 2  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 3  서울        전용면적 102㎡초과  2015  10    5879
# 4  인천         전용면적 60㎡이하  2015  10    3488

# %% [markdown]
# 2. 구글드라이브에서 가져오기(mount)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filename = '/content/drive/MyDrive/machine learning/house_price.csv'

# %%
import pandas as pd
data = pd.read_csv(filename)

# %%
data.head()
# Out:
#   지역명               규모구분    연도   월 분양가격(㎡)
# 0  서울         전용면적 60㎡이하  2015  10    5652
# 1  서울   전용면적 60㎡초과 85㎡이하  2015  10    5882
# 2  서울  전용면적 85㎡초과 102㎡이하  2015  10    5721
# 3  서울        전용면적 102㎡초과  2015  10    5879
# 4  인천         전용면적 60㎡이하  2015  10    3488
